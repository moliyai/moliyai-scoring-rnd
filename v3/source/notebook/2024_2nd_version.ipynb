# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel("../dataset/2nd_focus_data_selected.xlsx")

# %%
len(df)
# Out:
# 22007

# %%
df.head()
# Out:
#    client_id        fam         ism       sharif pseriya   praqam  \
# 0       4205  Xo'jayeva  Fazilatxon    Soxibovna      AB  5049225
# 1       4205  Xo'jayeva  Fazilatxon    Soxibovna      AB  5049225
# 2       4205  Xo'jayeva  Fazilatxon    Soxibovna      AB  5049225
# 3       4206     Azimov     Baxodir  Burxanovich      AD  1936212
# 4       4206     Azimov     Baxodir  Burxanovich      AD  1936212
#
#              pnfl  document_id                     pkb      narxi  ...  \
# 0  40801804250020            1  O'zbekiston tumani IIB  7963200.0  ...
# 1  40801804250020            1  O'zbekiston tumani IIB  7963200.0  ...
# 2  40801804250020            1  O'zbekiston tumani IIB  7963200.0  ...
# 3  32501844320017            1            Qoqon sh IIB   746304.0  ...
# 4  32501844320017            1            Qoqon sh IIB   746304.0  ...
#
#    deleted_at_x.1    id oila_status  oila_azo_soni  home_type  home_owner  \
# ...

# %%
df = df.sort_values(by='narxi', ascending=False)

# %%
df.head()
# Out:
#       client_id         fam          ism            sharif pseriya   praqam  \
# 8724       6701  Beknazarov         Isak    Ismailjonovich      AA  8277386
# 8725       6701  Beknazarov         Isak    Ismailjonovich      AA  8277386
# 9362       6890   O'lmasova  Marg'ubaxon         Salimovna      AD  2971482
# 9363       6890   O'lmasova  Marg'ubaxon         Salimovna      AD  2971482
# 1514       4647      Azamov     Murodjon  O'rmonjon o'g'li      AC   816313
#
#                 pnfl  document_id                          pkb        narxi  \
# 8724  30606874200099            1  Farg'ona v Uchko'prik t IIB  223000000.0
# 8725  30606874200099            1  Farg'ona v Uchko'prik t IIB  223000000.0
# 9362  41205824200080            1  Farg'ona v Uchko'prik t IIV  168000000.0
# 9363  41205824200080            1  Farg'ona v Uchko'prik t IIV  168000000.0
# 1514  50107027000019            1              O'zbekiston IIB  127569000.0
#
# ...

# %%
df = df.drop_duplicates(subset=['id'], keep='first').reset_index(drop=True)

# %%
df.head()
# Out:
#    client_id           fam          ism             sharif pseriya   praqam  \
# 0       6701    Beknazarov         Isak     Ismailjonovich      AA  8277386
# 1       6890     O'lmasova  Marg'ubaxon          Salimovna      AD  2971482
# 2       4647        Azamov     Murodjon   O'rmonjon o'g'li      AC   816313
# 3       5309      Normatov    Mansurjon  Maxamatjon o'g'li      AB  3093649
# 4       9413  Yunusaliyeva      Surayyo     Xabibullo qizi      AB  1104972
#
#              pnfl  document_id                                 pkb  \
# 0  30606874200099            1         Farg'ona v Uchko'prik t IIB
# 1  41205824200080            1         Farg'ona v Uchko'prik t IIV
# 2  50107027000019            1                     O'zbekiston IIB
# 3  31406924200058            1  Farg'ona vil. Uchkuprik tumani IIB
# 4  41108932120038            1                      Pop tumani IIB
#
#          narxi  ...  deleted_at_x.1    id oila_status  oila_azo_soni  \
# ...

# %%
len(df)
# Out:
# 6383

# %%
df.columns
# Out:
# Index(['client_id', 'fam', 'ism', 'sharif', 'pseriya', 'praqam', 'pnfl',
#        'document_id', 'pkb', 'narxi', 'soni', 'summa', 'izoh_x', 'muddat',
#        'btolov', 'marketing', 'xodim', 'pqb', 'ptm', 'phone1', 'phone2',
#        'birth_date', 'jins', 'viloyat_id', 'tuman_id', 'mfy_id', 'address',
#        'roy_address', 'orientr', 'client_status_y', 'status', 'tavsif',
#        'filial_id', 'user_id_x', 'created_at_x', 'updated_at_x',
#        'deleted_at_x', 'id_x', 'work_type_y', 'kasb_y', 'work_place_address_y',
#        'work_place_phone_y', 'work_place_phone_owner_y', 'lavozim_y',
#        'salary_y', 'card_status_y', 'work_place_y', 'work_tashkilot',
#        'user_id_y', 'created_at_y', 'updated_at_y', 'deleted_at_y', 'id_y',
#        'fio', 'qarindosh_status', 'ish_status', 'ish_faoliyat', 'ish_manzil',
#        'family_salary', 'user_id_x.1', 'created_at_x.1', 'updated_at_x.1',
#        'deleted_at_x.1', 'id', 'oila_status', 'oila_azo_soni', 'home_type',
# ...

# %%
df.rename(columns={
    'jins': 'sex',
    'viloyat_id': 'viloyat_id',
    'tuman_id': 'tuman_id', 
    'mfy_id': 'mfy_id',
    'client_status_y': 'client_type',
    'ish_faoliyat': 'job_name',
    'salary_y': 'salary',
    'family_salary': 'total_client_family_salary',
     'ish_status': 'occupation_status',
    'oila_status': 'family_status',
    'oila_azo_soni': 'family_members_count',
     'home_type': 'home_type',
    'home_owner': 'home_owner',
     'main_xarajat': 'client_monthly_expenditure',
    'narxi': 'product_price',
    'summa': 'final_product_price',
     'status':'status',

    


    # 'soni': 'quantity',
    # 'muddat':'duration',
    # 'birth_date': 'birth_date',
    # 'filial_id': 'branch_id',
    # 'lavozim_y': 'occupation',
    # 'qarindosh_status': 'relatives_status',
    # 'ish_manzil': 'work_place_address',

    }, inplace=True)

# %%
df.isnull().sum()
# Out:
# client_id                      0
# fam                            0
# ism                            0
# sharif                         0
# pseriya                        0
#                               ..
# home_owner                    26
# client_monthly_expenditure    91
# user_id_y.1                    0
# created_at_y.1                 0
# updated_at_y.1                 0
# Length: 72, dtype: int64

# %%
selected_df = df[[
    'sex', 'viloyat_id', 'tuman_id', 'mfy_id', 'client_type', 'job_name',
       'salary', 'total_client_family_salary', 'occupation_status',
       'family_status', 'family_members_count', 'home_type', 'home_owner',
       'client_monthly_expenditure', 'product_price', 'final_product_price',
       'status'
]]


selected_df.head()
# Out:
#    sex  viloyat_id  tuman_id  mfy_id  client_type        job_name     salary  \
# 0    1           6        87    6011          1.0            Usta  5000000.0
# 1    2           6        87    5989          1.0       Sanitarka  2500000.0
# 2    1           6        90    6071          1.0          Ishchi  3500000.0
# 3    1           6        87    6018          1.0         mexanik  7000000.0
# 4    2          13       183    6207          2.0  bola tarbiyasi  3500005.0
#
#    total_client_family_salary  occupation_status  family_status  \
# 0                   5000000.0                1.0              1
# 1                   2500000.0                1.0              1
# 2                   3500000.0                1.0              2
# 3                   7000000.0                1.0              1
# 4                    320000.0                1.0              1
#
#   family_members_count  home_type  home_owner client_monthly_expenditure  \
# ...

# %%
selected_df.isna().sum()
# Out:
# sex                             0
# viloyat_id                      0
# tuman_id                        0
# mfy_id                          0
# client_type                     1
# job_name                       40
# salary                         95
# total_client_family_salary    155
# occupation_status               6
# family_status                   0
# family_members_count           15
# home_type                      23
# home_owner                     26
# client_monthly_expenditure     91
# product_price                  53
# final_product_price            53
# status                          0
# dtype: int64

# %%
selected_df.dropna(inplace=True)
# Out:
# /tmp/ipykernel_15819/1556949007.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_df.dropna(inplace=True)

# %%
selected_df.isna().sum()
# Out:
# sex                           0
# viloyat_id                    0
# tuman_id                      0
# mfy_id                        0
# client_type                   0
# job_name                      0
# salary                        0
# total_client_family_salary    0
# occupation_status             0
# family_status                 0
# family_members_count          0
# home_type                     0
# home_owner                    0
# client_monthly_expenditure    0
# product_price                 0
# final_product_price           0
# status                        0
# dtype: int64

# %%
len(selected_df)
# Out:
# 6001

# %%
selected_df.head(15)
# Out:
#     sex  viloyat_id  tuman_id  mfy_id  client_type  \
# 0     1           6        87    6011          1.0
# 1     2           6        87    5989          1.0
# 2     1           6        90    6071          1.0
# 3     1           6        87    6018          1.0
# 4     2          13       183    6207          2.0
# 5     1           6        76    5789          2.0
# 6     1           6        90    6095          2.0
# 7     1           6        87    6010          1.0
# 8     2           6        76    5791          1.0
# 9     1           6        80    5976          1.0
# 10    1           6        80    5976          1.0
# 11    2           6        76    6187          2.0
# 12    1           6        90    6105          2.0
# 13    2           6        76    5758          1.0
# 14    1           6        76    5785          1.0
#
#                                 job_name      salary  \
# 0                                   Usta   5000000.0
# ...

# %%
selected_df["status"].value_counts()
# Out:
# Yakunlandi                   3945
# Komitet bekor qildi           957
# Monitoring bekor qildi        902
# Yangi                          86
# Bekor qilindi                  85
# Monitoringda                   22
# Komitet ko`rib chhiqmoqda       4
# Name: status, dtype: int64

# %%
selected_df["status"] = selected_df["status"].replace({"Yakunlandi": 0, "Monitoring bekor qildi": 1, "Komitet bekor qildi": 1, "Bekor qilindi": 1, "Yangi":1, "Monitoringda":1, "Komitet ko`rib chiqmoqda":1}).fillna(0)
# Out:
# /tmp/ipykernel_15819/4105154697.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_df["status"] = selected_df["status"].replace({"Yakunlandi": 0, "Monitoring bekor qildi": 1, "Komitet bekor qildi": 1, "Bekor qilindi": 1, "Yangi":1, "Monitoringda":1, "Komitet ko`rib chiqmoqda":1}).fillna(0)

# %%
selected_df["status"] = selected_df["status"].replace({"Komitet ko`rib chhiqmoqda":1}).fillna(0)
# Out:
# /tmp/ipykernel_15819/1680620190.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_df["status"] = selected_df["status"].replace({"Komitet ko`rib chhiqmoqda":1}).fillna(0)

# %%
selected_df['status'].value_counts()
# Out:
# 0    3945
# 1    2056
# Name: status, dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
x = selected_df.drop(["status"],axis=1)
y = selected_df["status"]

count_class = y.value_counts()
plt.bar(count_class.index, count_class.values)
plt.xlabel('Class')
plt.ylabel('Count')
plt.title('Class Distribution')
plt.xticks(count_class.index, ['Class 0', 'Class 1'])
plt.show()

# %% [markdown]
# class 0 - approved
# class 1 - not approved

# %%
obj_df = selected_df.select_dtypes(include=['object']).copy()

# %%
obj_df.head()
# Out:
#          job_name family_members_count client_monthly_expenditure
# 0            Usta                    6                    3000000
# 1       Sanitarka                    5                    2500000
# 2          Ishchi                    1                     400000
# 3         mexanik                    5                    2500000
# 4  bola tarbiyasi                    5                    2000000

# %%
def find_unique(col):
  print(col,":",obj_df[col].unique())
for col in obj_df.columns:
  find_unique(col)
# Out:
# job_name : ['Usta' 'Sanitarka' 'Ishchi' ... 'Xamkorlik buyicha Menijir' 'SOTUVCHI'
#  'bank muhandisi']
# family_members_count : [6 5 1 3 7 10 8 2 4 15 12 14 9 11 '7s23' 13 'None' 17 16 123]
# client_monthly_expenditure : [3000000 2500000 400000 2000000 1200000 2800000 1500000 2400000 5000000
#  3200000 3500000 1000000 4000000 1600000 15000000 7500000 4800000 5600000
#  35000000 800000 160000 680000 3600000 4500000 8000000 4400000 4200000
#  650000 6000000 16000000 25000000 350000 1800000 30000000 40000000 2200000
#  10000000 850000 1250000 500000 5500000 24000 1300000 6500000 120000
#  550000 45000000 1540000 250000 'None' 450000 1600 200000 2100000 28000000
#  '2 500 000' 5200000 600000 240000 12000000 1360000 750000 '2 500000'
#  '1 500 000' 300000 1400000 24000000 440000 5 1050000 2 0 2580000 6800000
#  6400000 450000000 50000000 20000000 31231]

# %%
selected_df['family_members_count'] = pd.to_numeric(selected_df['family_members_count'], errors='coerce')
# Out:
# /tmp/ipykernel_15819/3300029742.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_df['family_members_count'] = pd.to_numeric(selected_df['family_members_count'], errors='coerce')

# %%
selected_df['family_members_count'].dtype
# Out:
# dtype('float64')

# %%
# selected_df['birth_date'] = pd.to_datetime(selected_df['birth_date'], errors='coerce')

# %%
# selected_df['year'] = selected_df['birth_date'].dt.year

# %%
# selected_df['year'].head()
# Out:
# 0    1987.0
# 1    1982.0
# 2    2002.0
# 3    1992.0
# 4    1993.0
# Name: year, dtype: float64

# %%
# selected_df = selected_df.drop(['birth_date'], axis=1)

# %%
# selected_df['age'] = 2025 - selected_df['year']

# %%
# selected_df.head()
# Out:
#    product_price  quantity  duration  status  sex  client_type  branch_id  \
# 0    223000000.0       1.0        12       0    1          1.0          3
# 1    168000000.0       1.0        12       1    2          1.0          3
# 2    127569000.0       1.0        12       0    1          1.0          1
# 3     83610000.0       1.0        12       0    1          1.0          6
# 4     77878003.0       1.0        12       0    2          2.0          7
#
#       salary  relatives_status  occupation_status      profession  \
# 0  5000000.0               1.0                1.0            Usta
# 1  2500000.0               1.0                1.0       Sanitarka
# 2  3500000.0               1.0                1.0          Ishchi
# 3  7000000.0               1.0                1.0         mexanik
# 4  3500005.0               1.0                1.0  bola tarbiyasi
#
#    family_salary  family_status  family_members_count  home_type  home_owner  \
# ...

# %%
# shuffle the DataFrame rows
selected = selected_df.sample(frac = 1)

# %%
from sklearn.preprocessing import LabelEncoder

# %%
obj_df.head()
# Out:
#          job_name family_members_count client_monthly_expenditure
# 0            Usta                    6                    3000000
# 1       Sanitarka                    5                    2500000
# 2          Ishchi                    1                     400000
# 3         mexanik                    5                    2500000
# 4  bola tarbiyasi                    5                    2000000

# %%
selected_df['client_monthly_expenditure'] = pd.to_numeric(selected_df['client_monthly_expenditure'], errors='coerce')
# Out:
# /tmp/ipykernel_15819/4195075689.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_df['client_monthly_expenditure'] = pd.to_numeric(selected_df['client_monthly_expenditure'], errors='coerce')

# %%
selected_df.dtypes
# Out:
# sex                             int64
# viloyat_id                      int64
# tuman_id                        int64
# mfy_id                          int64
# client_type                   float64
# job_name                       object
# salary                        float64
# total_client_family_salary    float64
# occupation_status             float64
# family_status                   int64
# family_members_count          float64
# home_type                     float64
# home_owner                    float64
# client_monthly_expenditure    float64
# product_price                 float64
# final_product_price           float64
# status                          int64
# dtype: object

# %%
categorical_cols = selected_df.select_dtypes(include=['object']).columns

# %%
categorical_cols = selected_df.select_dtypes(exclude=['number']).columns

# %%
categorical_cols
# Out:
# Index(['job_name'], dtype='object')

# %%
# encode the categorical values into numeric values
le=LabelEncoder()
for col in categorical_cols:
    selected_df[col] = selected_df[col].astype(str)  # Convert to string
    selected_df[col] = le.fit_transform(selected_df[col])  # Apply Label Encoding
# Out:
# /tmp/ipykernel_15819/13155019.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_df[col] = selected_df[col].astype(str)  # Convert to string
# /tmp/ipykernel_15819/13155019.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_df[col] = le.fit_transform(selected_df[col])  # Apply Label Encoding

# %%
selected_df.head()
# Out:
#    sex  viloyat_id  tuman_id  mfy_id  client_type  job_name     salary  \
# 0    1           6        87    6011          1.0      1042  5000000.0
# 1    2           6        87    5989          1.0       769  2500000.0
# 2    1           6        90    6071          1.0       285  3500000.0
# 3    1           6        87    6018          1.0      1561  7000000.0
# 4    2          13       183    6207          2.0      1383  3500005.0
#
#    total_client_family_salary  occupation_status  family_status  \
# 0                   5000000.0                1.0              1
# 1                   2500000.0                1.0              1
# 2                   3500000.0                1.0              2
# 3                   7000000.0                1.0              1
# 4                    320000.0                1.0              1
#
#    family_members_count  home_type  home_owner  client_monthly_expenditure  \
# ...

# %%
selected_df.reset_index(inplace=True)
selected_df.head()
# Out:
#    index  sex  viloyat_id  tuman_id  mfy_id  client_type  job_name     salary  \
# 0      0    1           6        87    6011          1.0      1042  5000000.0
# 1      1    2           6        87    5989          1.0       769  2500000.0
# 2      2    1           6        90    6071          1.0       285  3500000.0
# 3      3    1           6        87    6018          1.0      1561  7000000.0
# 4      4    2          13       183    6207          2.0      1383  3500005.0
#
#    total_client_family_salary  occupation_status  family_status  \
# 0                   5000000.0                1.0              1
# 1                   2500000.0                1.0              1
# 2                   3500000.0                1.0              2
# 3                   7000000.0                1.0              1
# 4                    320000.0                1.0              1
#
#    family_members_count  home_type  home_owner  client_monthly_expenditure  \
# ...

# %%
data = selected_df.drop(columns=["index"],axis=1)
data.head()
# Out:
#    sex  viloyat_id  tuman_id  mfy_id  client_type  job_name     salary  \
# 0    1           6        87    6011          1.0      1042  5000000.0
# 1    2           6        87    5989          1.0       769  2500000.0
# 2    1           6        90    6071          1.0       285  3500000.0
# 3    1           6        87    6018          1.0      1561  7000000.0
# 4    2          13       183    6207          2.0      1383  3500005.0
#
#    total_client_family_salary  occupation_status  family_status  \
# 0                   5000000.0                1.0              1
# 1                   2500000.0                1.0              1
# 2                   3500000.0                1.0              2
# 3                   7000000.0                1.0              1
# 4                    320000.0                1.0              1
#
#    family_members_count  home_type  home_owner  client_monthly_expenditure  \
# ...

# %%
import seaborn as sns

# %%
# correlation matrix of DataFrame
plt.figure(figsize=(20,10))
corn = data.corr()
sns.heatmap(corn,annot=True,cmap="BuPu")
# Out:
# <Axes: >

# %%
# from sklearn.preprocessing import StandardScaler
# import re

# %%
# for col in data.columns:
#     if data[col].dtype == 'object':  # Check object columns
#         print(f"Column {col} unique values: {data[col].unique()}")

# %%
# data = data.apply(pd.to_numeric, errors='coerce')  # Convert to numbers
# print(data.isna().sum())  # Check if any NaN values were introduced
# Out:
# product_price                 0
# quantity                      0
# duration                      0
# status                        0
# sex                           0
# client_type                   0
# branch_id                     0
# salary                        0
# relatives_status              0
# occupation_status             0
# profession                    0
# family_salary                 0
# family_status                 0
# family_members_count          3
# home_type                     0
# home_owner                    0
# client_monthly_expenditure    7
# year                          3
# age                           3
# dtype: int64

# %%
data = data.fillna(data.mean())

# %%
from imblearn.over_sampling import SMOTE

# %%
X = data.drop(columns=['status'])
y = data['status']

# %%
y = y.astype(int)

# %%
smote = SMOTE(random_state=42)
X_resampled, y_resampled = smote.fit_resample(X, y)

# %%
print(y_resampled.value_counts())
# Out:
# 1    3945
# 0    3945
# Name: status, dtype: int64

# %%
df_balanced = pd.DataFrame(X_resampled, columns=X.columns)
df_balanced['status'] = y_resampled

# %%
print(df_balanced['status'].value_counts())  # Check balance
# Out:
# 1    3945
# 0    3945
# Name: status, dtype: int64

# %%
df_balanced['status'].value_counts()
# Out:
# 1    3945
# 0    3945
# Name: status, dtype: int64

# %%
# shuffle the DataFrame rows
df_balanced = df_balanced.sample(frac = 1)

# %%
df_balanced.head()
# Out:
#       sex  viloyat_id  tuman_id  mfy_id  client_type  job_name      salary  \
# 3635    1          13       183    6201          1.0        30  10000000.0
# 3203    1           6        76    5791          1.0      1541   4000000.0
# 1518    2           6        87    6005          1.0       597   1500000.0
# 334     1           6        87    6015          1.0      1752   5000000.0
# 3734    1           6        80    5961          1.0      1958   4500000.0
#
#       total_client_family_salary  occupation_status  family_status  \
# 3635                  10000000.0                1.0              1
# 3203                   4000000.0                1.0              1
# 1518                   3800000.0                1.0              1
# 334                    7000000.0                2.0              1
# 3734                   4500000.0                1.0              1
#
#       family_members_count  home_type  home_owner  client_monthly_expenditure  \
# ...

# %%
df_balanced.rename(columns={
    'final_product_price': 'final_produt_price',
    }, inplace=True)

# %%
df_balanced.head()
# Out:
#       sex  viloyat_id  tuman_id  mfy_id  client_type  job_name      salary  \
# 3635    1          13       183    6201          1.0        30  10000000.0
# 3203    1           6        76    5791          1.0      1541   4000000.0
# 1518    2           6        87    6005          1.0       597   1500000.0
# 334     1           6        87    6015          1.0      1752   5000000.0
# 3734    1           6        80    5961          1.0      1958   4500000.0
#
#       total_client_family_salary  occupation_status  family_status  \
# 3635                  10000000.0                1.0              1
# 3203                   4000000.0                1.0              1
# 1518                   3800000.0                1.0              1
# 334                    7000000.0                2.0              1
# 3734                   4500000.0                1.0              1
#
#       family_members_count  home_type  home_owner  client_monthly_expenditure  \
# ...

# %%
df_balanced.to_csv("../dataset/cleaned_final_df_2025.csv", index=False)

# %%
# # Initialize StandardScaler
# scaler = StandardScaler()

# %%
# # Apply scaling
# df_scaled = pd.DataFrame(scaler.fit_transform(df_balanced), columns=df_balanced.columns)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle

# %%
df = df_balanced.copy()
# shuffle the DataFrame rows
df = df.sample(frac = 1)

# %%
df.head()
# Out:
#       sex  viloyat_id  tuman_id  mfy_id  client_type  job_name        salary  \
# 7400    1           9       130    6061          1.0      1350  3.500000e+06
# 6989    1           6        84    5934          1.0      1666  7.730818e+06
# 6358    1           6        84    5976          1.0       926  3.691750e+06
# 663     2           6        76    5792          1.0       180  2.000000e+05
# 2319    2           6        90    6071          2.0       923  4.000000e+06
#
#       total_client_family_salary  occupation_status  family_status  \
# 7400                3.727747e+06                1.0              1
# 6989                8.000000e+06                1.0              1
# 6358                7.691750e+05                1.0              1
# 663                 6.000000e+06                1.0              1
# 2319                4.000000e+06                1.0              1
#
#       family_members_count  home_type  home_owner  client_monthly_expenditure  \
# ...

# %%
df['status'].value_counts()
# Out:
# 1    3945
# 0    3945
# Name: status, dtype: int64

# %%
len(df)
# Out:
# 7890

# %%
# shuffle the DataFrame rows
df = df.sample(frac = 1)

# %%
X = df.drop(columns=['status'])
y = df['status']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
rf = RandomForestClassifier(n_estimators=50, max_depth=10, random_state=42)
rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(max_depth=10, n_estimators=50, random_state=42)

# %%
# Evaluate
print("Train Accuracy:", rf.score(X_train, y_train))
print("Test Accuracy:", rf.score(X_test, y_test))
# Out:
# Train Accuracy: 0.8533405757740359
# Test Accuracy: 0.7832699619771863

# %%
from sklearn.metrics import classification_report, confusion_matrix

y_pred = rf.predict(X_test)
print("Classification Report:\n", classification_report(y_test, y_pred))
print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred))
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.77      0.80      0.79      1170
#            1       0.80      0.76      0.78      1197
#
#     accuracy                           0.78      2367
#    macro avg       0.78      0.78      0.78      2367
# weighted avg       0.78      0.78      0.78      2367
#
# Confusion Matrix:
#  [[940 230]
#  [283 914]]

# %%
from sklearn.model_selection import cross_val_score
cv_scores = cross_val_score(rf, X, y, cv=10)  # 10-fold cross-validation
print(f"Cross-validation scores: {cv_scores}")
print(f"Mean cross-validation score: {cv_scores.mean()}")
# Out:
# Cross-validation scores: [0.77059569 0.77313054 0.77059569 0.77313054 0.76299113 0.76679341
#  0.77313054 0.77820025 0.78707224 0.77186312]
# Mean cross-validation score: 0.7727503168567809

# %%
feature_importances = pd.DataFrame(rf.feature_importances_,
                                   index=X_train.columns,
                                   columns=["importance"]).sort_values("importance", ascending=False)
print(feature_importances)
# Out:
#                             importance
# client_type                   0.246047
# final_produt_price            0.120877
# product_price                 0.119236
# tuman_id                      0.082004
# mfy_id                        0.076772
# job_name                      0.062959
# salary                        0.043462
# viloyat_id                    0.043271
# client_monthly_expenditure    0.041163
# family_members_count          0.039931
# total_client_family_salary    0.039060
# sex                           0.038665
# home_type                     0.037490
# family_status                 0.003567
# occupation_status             0.002986
# home_owner                    0.002510

# %%
from sklearn.model_selection import GridSearchCV

param_grid = {
    'n_estimators': [50, 100, 150],
    'max_depth': [5, 10, 15],
    'min_samples_split': [2, 5, 10]
}

grid_search = GridSearchCV(RandomForestClassifier(random_state=42), param_grid, cv=5, n_jobs=-1)
grid_search.fit(X_train, y_train)
print("Best hyperparameters:", grid_search.best_params_)
# Out:
# Best hyperparameters: {'max_depth': 15, 'min_samples_split': 2, 'n_estimators': 150}

# %%
r = RandomForestClassifier(n_estimators=130, max_depth=8, random_state=42)
r.fit(X_train, y_train)
# Out:
# RandomForestClassifier(max_depth=8, n_estimators=130, random_state=42)

# %%
# Evaluate
print("Train Accuracy:", r.score(X_train, y_train))
print("Test Accuracy:", r.score(X_test, y_test))
# Out:
# Train Accuracy: 0.8240264511388685
# Test Accuracy: 0.7536418166238218

# %%
from sklearn.metrics import roc_auc_score
y_pred_prob = rf.predict_proba(X_test)[:, 1]  # Probabilities for class 1
print("ROC AUC Score:", roc_auc_score(y_test, y_pred_prob))
# Out:
# ROC AUC Score: 0.8484551072337332

# %%
from sklearn.metrics import roc_curve
# Compute the false positive rate (FPR) 
# and true positive rate (TPR) for different classification thresholds 
fpr, tpr, thresholds = roc_curve(y_test, y_pred_prob, pos_label=1)

# %%
# Compute the ROC AUC score 
roc_auc = roc_auc_score(y_test, y_pred_prob) 
roc_auc
# Out:
# 0.8484551072337332

# %%
# Plot the ROC curve 
plt.plot(fpr, tpr, label='ROC curve (area = %0.2f)' % roc_auc) 
# roc curve for tpr = fpr 
plt.plot([0, 1], [0, 1], 'k--', label='Random classifier') 
plt.xlabel('False Positive Rate') 
plt.ylabel('True Positive Rate') 
plt.title('ROC Curve') 
plt.legend(loc="lower right") 
plt.show()

# %%
# import pickle
# model_name = '../model/2025_2nd_version.pkl'
# pickle.dump(rf, open(model_name, 'wb'))
