# %%
import pandas as pd

# %%
df = pd.read_excel("../dataset/data.xlsx")

# %%
df.columns
# Out:
# Index(['client_id', 'fam', 'ism', 'sharif', 'pseriya', 'praqam', 'document_id',
#        'pkb', 'pqb', 'ptm', 'pnfl', 'phone1', 'phone2', 'birth_date', 'jins',
#        'viloyat_id', 'tuman_id', 'mfy_id', 'address', 'roy_address', 'orientr',
#        'work_type', 'kasb', 'work_place_address', 'work_place_phone',
#        'work_place_phone_owner', 'lavozim', 'salary', 'card_status',
#        'work_place', 'work_place_name', 'client_status', 'status', 'tavsif',
#        'filial_id', 'user_id', 'created_at', 'updated_at', 'deleted_at',
#        'work_type_client_sorovnoma_finances.xlsx',
#        'kasb_client_sorovnoma_finances.xlsx',
#        'work_place_address_client_sorovnoma_finances.xlsx',
#        'work_place_phone_client_sorovnoma_finances.xlsx',
#        'work_place_phone_owner_client_sorovnoma_finances.xlsx',
#        'lavozim_client_sorovnoma_finances.xlsx',
#        'salary_client_sorovnoma_finances.xlsx',
#        'card_status_client_sorovnoma_finances.xlsx',
# ...

# %%
selected_columns = [
    "client_id", "fam", "ism", "sharif", "pseriya", "praqam", "pnfl", "phone1", "phone2", "birth_date", "jins", "viloyat_id","tuman_id", "mfy_id", "client_status", "status", "work_type_client_sorovnoma_finances.xlsx",
    "kasb_client_sorovnoma_finances.xlsx", "work_place_phone_client_sorovnoma_finances.xlsx",
    "work_place_phone_owner_client_sorovnoma_finances.xlsx", "lavozim_client_sorovnoma_finances.xlsx", "salary_client_sorovnoma_finances.xlsx", "ish_faoliyat", "salary_client_sorovnoma_oilas.xlsx", "ish_status", "oila_status", "oila_azo_soni", "home_type", "home_type", "home_owner", "main_xarajat", "narxi", "summa"
]

# %%
extracted_data = df[selected_columns]

# %%
extracted_data
# Out:
#       client_id            fam         ism            sharif pseriya   praqam  \
# 0             3    Imomnazarov    Islomjon  Ramishjon o'g'li      AC  2507350
# 1             4  Meliqo`ziyeva  Muslimaxon    Farxodjon qizi      AA  8312668
# 2             5       Asqarova    Dilshoda        Ergashevna      AC  2979026
# 3             6        Nosirov     Azizbek   Kozimjon O'g'li      AB  1732823
# 4             7        Akramov      Alixon        Akbarovich      AA  6311205
# ...         ...            ...         ...               ...     ...      ...
# 6561       6902        Isakova    Muyassar      Anvarjanovna      AC  1159792
# 6562       6903        Uzoqova      Sojida      Turdaliyevna      AA  8189646
# 6563       6904       Soliyeva       Barno         Saminovna      AD  7310330
# 6564       6905      Qurbonova     Zulfiya     Abduxamedovna      AB  7422596
# 6565       6906        Evatova      Feruza      Kaxramanovna      AC  2753361
#
# ...

# %%
extracted_data.to_csv("extracted_data.csv", index=False)
